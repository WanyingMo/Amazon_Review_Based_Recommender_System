# %%
import json, csv, os
import pandas as pd
from tqdm import tqdm
from random import sample

# %%
data_dir = "../Data/"

# %% [markdown]
# ### Pass 1 - Get a mapping of users and number of reviews

# %%
user_item_dict = {}
def populate_user_item_dict(data_path, total_rows):
    with open(data_path, encoding="utf-8") as file:
        with tqdm(total=total_rows, desc="Processing", leave=True, unit_scale=True) as pbar:
            for line in file:
                    row = json.loads(line)
                    uid = row.get("reviewerID")
                    user_item_dict[uid] = user_item_dict.get(uid, 0) + 1
                    pbar.update()

# %%
data_path = os.path.join(data_dir, "All_Amazon_Review_5.json")
total_rows = 157260921
populate_user_item_dict(data_path, total_rows)

# %%
with open(os.path.join(data_dir, "user_reviews.json")) as file:
    json.dump(user_item_dict)

# %% [markdown]
# ### Pass 2 - Sample Data

# %%
with open("./user_reviews.json") as file:
    user_reviews_dict = json.load(file)

# %%
frequent_reviewers = [key for key, val in user_reviews_dict.items() if val > 10]
print(len(frequent_reviewers))
# Out:
# 4198335

# %%
users_100k = set(sample(frequent_reviewers, 100000))
users_500k = set(sample(frequent_reviewers, 500000))
print(len(users_100k), len(users_500k))
# Out:
# 100000 500000

# %%
def sampleDataJSON(totalSize:int, dataPath:str, output_100k:str, output_500k:str, columns:list):
    """function used to sample a small csv dataset from a large JSON file

    Args:
        totalSize (int): the size of the original dataset
        dataPath (str): original dataset path
        output_100k (str): sample_100k dataset output path
        output_500k (str): sample_500k dataset output path
        columns (list): list of cloumn required in the sampled dataset
    """

    with open(output_100k, "w", newline="") as output_100k, \
    open(output_500k, "w", newline="") as output_500k:

        writer_100k = csv.DictWriter(output_100k, columns)
        writer_100k.writeheader()
        writer_500k = csv.DictWriter(output_500k, columns)
        writer_500k.writeheader()
        
        with open(dataPath, encoding="utf-8") as file:
            with tqdm(total=totalSize, desc="Processing", leave=True, unit_scale=True) as pbar:
                for line in file:
                    row = json.loads(line)
                    uid = row.get("reviewerID")
                    if uid in users_100k:
                        writer_100k.writerow(dict([(key, row.get(key, "")) for key in columns]))
                    if uid in users_500k:
                        writer_500k.writerow(dict([(key, row.get(key, "")) for key in columns]))
                    pbar.update()
    
                    
data_dir = "../Data/"
input_json_path = os.path.join(data_dir, "All_Amazon_Review_5.json")
output_100k = os.path.join(data_dir, "sampled_100k.csv")
output_500k = os.path.join(data_dir, "sampled_500k.csv")
total_records = 157260921
columns = ['verified', 'asin', 'reviewerID', 'overall', 'reviewText', 'unixReviewTime', 'summary', 'vote']
sampleDataJSON(total_records, input_json_path, output_100k, output_500k, columns)
# Out:
# Processing: 100%|█████████▉| 157M/157M [1:01:58<00:00, 42.3kit/s]

# %% [markdown]
# ### Train - Validation - Test Split

# %%
df = pd.read_csv(os.path.join(data_dir, "sampled_100k.csv"), low_memory = False)

# %%
df.sort_values(['reviewerID', 'unixReviewTime'], ascending=[True, False], inplace=True)
df.reset_index(drop=True, inplace=True)

def update(val):
    if type(val) == str:
        val = val.replace(",", "")
    return int(val)

df.vote = df.vote.fillna(0).apply(update)

# %%
df.head(30)
# Out:
#     verified        asin            reviewerID  overall  \
# 0       True  B00ZJRHSRW  A0003492LQH8LJXPWDMZ      3.0
# 1       True  B01FY9XN00  A0003492LQH8LJXPWDMZ      5.0
# 2       True  B00U0I3N4M  A0003492LQH8LJXPWDMZ      5.0
# 3       True  B00DJACZ56  A0003492LQH8LJXPWDMZ      5.0
# 4       True  B01F88RU6U  A0003492LQH8LJXPWDMZ      2.0
# 5       True  B01FY9XN00  A0003492LQH8LJXPWDMZ      3.0
# 6      False  B004PBCFG2  A0003492LQH8LJXPWDMZ      1.0
# 7       True  0373799713  A0003492LQH8LJXPWDMZ      5.0
# 8      False  B01BXL5I88  A0003492LQH8LJXPWDMZ      2.0
# 9       True  B018GEHIW4  A0003492LQH8LJXPWDMZ      5.0
# 10      True  B00VX7H7E6  A0003492LQH8LJXPWDMZ      5.0
# 11      True  B012VIRMZE  A0003492LQH8LJXPWDMZ      5.0
# 12      True  B00I95O5N6  A0003492LQH8LJXPWDMZ      3.0
# 13      True  B01GFN845S  A0003492LQH8LJXPWDMZ      5.0
# 14      True  B00XWE5TB6  A0003492LQH8LJXPWDMZ      1.0
# 15      True  B004K1AMIU  A0003492LQH8LJXPWDMZ      5.0
# 16      True  B0075079JS  A0003492LQH8LJXPWDMZ      1.0
# 17      True  1601065701  A0003492LQH8LJXPWDMZ      5.0
# 18      True  B00DSTBM6G  A0003492LQH8LJXPWDMZ      5.0
# 19      True  B00KRMS12A  A0003492LQH8LJXPWDMZ      3.0
# 20      True  B00CPOY2AS  A0003492LQH8LJXPWDMZ      1.0
# 21     False  B00EZM7QVK  A0003492LQH8LJXPWDMZ      3.0
# 22     False  1983730742   A0020356UF96ZV361ST      4.0
# 23     False  1977509118   A0020356UF96ZV361ST      4.0
# 24      True  B01FL44RL2   A0020356UF96ZV361ST      5.0
# 25     False  1946870064   A0020356UF96ZV361ST      4.0
# 26     False  1549627813   A0020356UF96ZV361ST      4.0
# 27     False  1545304718   A0020356UF96ZV361ST      4.0
# 28     False  1543131441   A0020356UF96ZV361ST      4.0
# 29     False  B010CDL9LI   A0020356UF96ZV361ST      4.0
#
#                                            reviewText  unixReviewTime  \
# 0   So the shipping box was fine, but the actual b...      1524787200
# 1   Product is great! This is my 3rd pair. There p...      1522886400
# 2   Great quality. Fit as expected. Boyfriend wear...      1508025600
# 3           Cute design and keeps my car a lot cooler      1508025600
# 4   Super cute top, however only got to wear once ...      1508025600
# 5   Decent material, the shorts were a bit bigger ...      1504569600
# 6   The stand it's self is a bit smaller than I ex...      1504569600
# 7         Love the blaze series!! Always a good read!      1504137600
# 8   Cute gift, boyfriend loved it, but cheaply mad...      1502668800
# 9   Very cute shakers. Packaged very securely with...      1494633600
# 10  Excellent quality. Very bright and I love that...      1494633600
# 11  Very bright and the different modes make it fu...      1494633600
# 12  Nice shorts, however there too big for me to wear      1490832000
# 13  Very impressed with these dresses! Ordered 8 d...      1477958400
# 14  Unfortunately way to small and wasn't able to ...      1466553600
# 15  Exactly what I was looking for. Perfect size I...      1466553600
# 16  Only came with one key chain. Useless without ...      1466553600
# 17  Excellent product. Exactly what I'm looking fo...      1466553600
# 18                     Work well, good for the price.      1443571200
# 19  Very cute, but this was more of an extra small...      1437868800
# 20                                    broke my phone.      1410825600
# 21  it looks like a computer image was placed on i...      1410825600
# 22  Omg heaven is sleeping with her abusive husban...      1516924800
# 23  This is one crazy family, the father beats the...      1507593600
# 24                                    My son loves it      1506470400
# 25  Why did she put up with the abuse for so long,...      1506038400
# 26  She has been in group homes her whole life so ...      1505088000
# 27  I can't put these books down. K  has finally a...      1503446400
# 28  Two cousins trying to make it, one has a disab...      1503187200
# 29  Mai  was in an abusive relationship, when she ...      1502841600
#
#                                               summary  vote
# 0                                          Lose parts     0
# 1               Product is great! This is my 3rd pair     0
# 2                                          Five Stars     0
# 3                                          Five Stars     0
# 4                                          Fringe bad     0
# 5                       Overall not bad for the price     0
# 6     The stand it's self is a bit smaller than I ...     0
# 7                                          Five Stars     0
# 8                boyfriend loved it, but cheaply made     0
# 9                       Absolutely love this purchase     0
# 10  Excellent quality. Very bright and I love that...     0
# 11                                         Five Stars     0
# 12                                        Three Stars     0
# 13                               Beautiful dresses!!!    29
# 14                                      Way to small!     0
# 15                              Perfect size I needed     0
# 16                          Useless without the other     0
# 17                                          Excellent     0
# 18                                             5 star     0
# 19                                      Sizing is off     0
# 20                                           One Star     0
# 21                                        Three Stars     0
# 22                                               Sh*t     0
# 23                                                Wow     0
# 24                                         Five Stars     0
# 25                                                Wow     0
# 26                                              Shoot     2
# 27                                                Omg     0
# 28                                                Omg     0
# 29                                                Wow     0

# %%
start = 0
count = len(pd.unique(df.reviewerID))

train_indices = []
validation_indices = []
test_indices = []

with tqdm(total=count, desc="Processing", leave=True, unit_scale=True) as pbar:
    for i in range(count):
        uid = df.iloc[start, :].reviewerID
        num_records = user_reviews_dict.get(uid)
        test_indices.extend(list(range(start, start + int(num_records * 0.2))))
        validation_indices.extend(list(range(start + int(num_records * 0.2), start + int(num_records * 0.4))))
        train_indices.extend(list(range(start + int(num_records * 0.4), start + num_records)))
        start += num_records
        pbar.update()
# Out:
# Processing: 100%|██████████| 100k/100k [00:21<00:00, 4.63kit/s]

# %%
train_100k = df.iloc[train_indices]
train_100k.reset_index(drop=True, inplace=True)
train_100k.to_csv(os.path.join(data_dir, "train_100k.csv"), index=False)
validation_100k = df.iloc[validation_indices]
validation_100k.reset_index(drop=True, inplace=True)
validation_100k.to_csv(os.path.join(data_dir, "validation_100k.csv"), index=False)
test_100k = df.iloc[test_indices]
test_100k.reset_index(drop=True, inplace=True)
test_100k.to_csv(os.path.join(data_dir, "test_100k.csv"), index=False)
